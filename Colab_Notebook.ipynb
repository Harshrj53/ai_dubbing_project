# %% [markdown]
# # AI Hindi Video Dubbing Pipeline - Colab Setup
# This notebook sets up the environment and runs the modular dubbing pipeline.

# %%
# 1. Install System Dependencies
# !apt-get update && apt-get install -y ffmpeg

# 2. Install Python Libraries
# !pip install faster-whisper transformers TTS git+https://github.com/openai/whisper.git

# 3. Clone Repository (Simulated for this local demo)
# !git clone https://github.com/your-repo/ai-dubbing.git
# %cd ai-dubbing

# %%
# 4. Run the Pipeline
# Upload your video to the sidebar first
import os
input_path = 'sample.mp4'
if os.path.exists(input_path):
    # !python dub_video.py --input {input_path} --output output_hindi_dub.mp4
else:
    print("Please upload a file named sample.mp4 to continue.")
